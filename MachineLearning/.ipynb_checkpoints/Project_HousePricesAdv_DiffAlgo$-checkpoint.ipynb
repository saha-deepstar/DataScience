# %% [markdown]
# ## -----------------------------------------------S  T  A  R  T--------------------------------------------------------

# %% [markdown]
# # Part-I
# ## Imorting modules
# ## Loading of Dataset
# ## Checking of Dataset ---> Nos. of Features, Datatypes of Features

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import os
os.getcwd()
# Out:
# 'C:\\Users\\sahar\\OneDrive\\Documents\\DataScience_LB\\LB_DSC_Modules\\02_Stats+ML\\02_Stats+ML_16APR_Classes\\Project-1_HousePricesAdv'

# %%
# Loading Train Dataset

train_data = pd.read_csv("train.csv")
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# Loading Test Dataset

test_data = pd.read_csv("test.csv")
test_data.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
print('Shape of Train Data: ', train_data.shape)
print('Shape of Test Data: ', test_data.shape)
# Out:
# Shape of Train Data:  (1460, 81)
# Shape of Test Data:  (1459, 80)

# %%
# Merging train and Test dataset and separating response variable

y = train_data.SalePrice
train_data.drop(columns='SalePrice', inplace=True)
dataset = pd.concat([train_data, test_data])

print('Shape of Merged Dataset: ', dataset.shape)
print('Shape of Response Dataframe: ', y.shape)
# Out:
# Shape of Merged Dataset:  (2919, 80)
# Shape of Response Dataframe:  (1460,)

# %%
# Preparing Submission DataFrame and dropping 'Id' from merged dataset

sub_data = pd.DataFrame()
sub_data['Id'] = test_data.Id

dataset.drop('Id', axis=1, inplace=True)
dataset.shape
# Out:
# (2919, 79)

# %%
# Checking of info of main dataframe after dropping Sr. No. Col

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 0 to 1458
# Data columns (total 79 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2915 non-null   object
#  2   LotFrontage    2433 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2917 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
# ...

# %% [markdown]
# # Part-II
# # Handling of Missing Values
#
# ### a) Splitting of Dataset into Categorical & Numerical Features
# ### b) Checking of Ordinal Categorical Variables in Numerical Features
# ### c) Combining Ordinal Features into Categorical Features and exclusion of the same from Numerical Dataframe
# ### d) Handling of missing values in Categorical Dataframe
# ### e) Handling of missing values in Numerical Dataframe

# %%
# Spliting the main dataframe as per types namely : Categorical and Continuous Data

categorical_data = dataset.loc[:, dataset.dtypes==np.object]
numerical_data = dataset.loc[:, dataset.dtypes!=np.object]

# Checking the shapes of 2 new dataframes created 

print(categorical_data.shape)
print(numerical_data.shape)
# Out:
# (2919, 43)
# (2919, 36)

# %%
# By checking total number of features it seems the main dataframe is splitted properly between 2 new dataframes

# checking of features in numerical dataframe
print(numerical_data.columns)
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold'],
#       dtype='object')

# %%
# Now in numerical variable we must look for Categorical Ordinal Variable (as some of these variable may be number format)
# Checking the number of unique values present in each numerical variable

numerical_data.nunique()
# Out:
# MSSubClass         16
# LotFrontage       128
# LotArea          1951
# OverallQual        10
# OverallCond         9
# YearBuilt         118
# YearRemodAdd       61
# MasVnrArea        444
# BsmtFinSF1        991
# BsmtFinSF2        272
# BsmtUnfSF        1135
# TotalBsmtSF      1058
# 1stFlrSF         1083
# 2ndFlrSF          635
# LowQualFinSF       36
# GrLivArea        1292
# BsmtFullBath        4
# BsmtHalfBath        3
# FullBath            5
# HalfBath            3
# BedroomAbvGr        8
# KitchenAbvGr        4
# TotRmsAbvGrd       14
# Fireplaces          5
# GarageYrBlt       103
# GarageCars          6
# GarageArea        603
# WoodDeckSF        379
# OpenPorchSF       252
# EnclosedPorch     183
# 3SsnPorch          31
# ScreenPorch       121
# PoolArea           14
# MiscVal            38
# MoSold             12
# YrSold              5
# dtype: int64

# %%
# Further checking of unique values of some variables along with reading data description

print(numerical_data['MSSubClass'].unique())
print(numerical_data['OverallQual'].unique())
print(numerical_data['OverallCond'].unique())
print(numerical_data['MoSold'].unique())
print(numerical_data['YrSold'].unique())
# Out:
# [ 60  20  70  50 190  45  90 120  30  85  80 160  75 180  40 150]
# [ 7  6  8  5  9  4 10  3  1  2]
# [5 8 6 7 4 2 3 9 1]
# [ 2  5  9 12 10  8 11  4  1  7  3  6]
# [2008 2007 2006 2009 2010]

# %%
# Above variables can be presented as ordinal relationship

cat_ord_var = ['MSSubClass', 'OverallQual', 'OverallCond', 'MoSold', 'YrSold']

# %%
# Re-arranging the categorical and numerical data

categorical_data = pd.concat([categorical_data, numerical_data[cat_ord_var].astype(str)], axis=1)

numerical_data = numerical_data.drop(columns=cat_ord_var, axis=1)

# %%
print(categorical_data.shape)
print(numerical_data.shape)
# Out:
# (2919, 48)
# (2919, 31)

# %%
# Craeting function to chart out the features contains more than 25% Null Values
# Default threshold percentage is 25%

def NullDrop(df, n=0.25):
    s = pd.Series((df.isnull().sum()/len(df)), name='Values')
    data = s.to_frame()
    data = data[(data['Values']>n)]
    
    return data

# %%
# we have to drop the features having more than 25% Null Values

categorical_data_drop = NullDrop(categorical_data)
numerical_data_drop = NullDrop(numerical_data)

# %%
# DataFrame containg the Categorical Features having more than 25% Null Values

categorical_data_drop
# Out:
#                Values
# Alley        0.932169
# FireplaceQu  0.486468
# PoolQC       0.996574
# Fence        0.804385
# MiscFeature  0.964029

# %%
# Dropping above 5 features from Categorical Data

categorical_data = categorical_data.drop(columns=['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], axis=1)

# %%
# Cross-checking the shape of old and new categorical dataframe

print(categorical_data.shape)
# Out:
# (2919, 43)

# %%
# DataFrame containing the Categorical Features having more than 25% Null Values

numerical_data_drop
# Out:
# Empty DataFrame
# Columns: [Values]
# Index: []

# %%
# There are 5 Categorical Features those are dropped
# Ther is no Numerical Features having more than 25% of Missing Data

# %%
# Craeting function to chart out the features contains less than 25% (& > 0%) Null Values
# Default threshold percentage is 25%
# These features we need to handle through Imputation Techniques

def NullImpute(df, n=0.25):
    s = pd.Series((df.isnull().sum()/len(df)), name='Values')
    data = s.to_frame()
    data = data[((data['Values']<=n) & (data['Values']>0))]
    
    return data

# %%
cat_imp = NullImpute(categorical_data)
num_imp = NullImpute(numerical_data)

# %%
# DataFrame containing the Categorical Features needs to be treated

cat_imp
# Out:
#                 Values
# MSZoning      0.001370
# Utilities     0.000685
# Exterior1st   0.000343
# Exterior2nd   0.000343
# MasVnrType    0.008222
# BsmtQual      0.027749
# BsmtCond      0.028092
# BsmtExposure  0.028092
# BsmtFinType1  0.027064
# BsmtFinType2  0.027407
# Electrical    0.000343
# KitchenQual   0.000343
# Functional    0.000685
# GarageType    0.053786
# GarageFinish  0.054471
# GarageQual    0.054471
# GarageCond    0.054471
# SaleType      0.000343

# %%
cat_imp.index
# Out:
# Index(['MSZoning', 'Utilities', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Electrical', 'KitchenQual', 'Functional', 'GarageType', 'GarageFinish',
#        'GarageQual', 'GarageCond', 'SaleType'],
#       dtype='object')

# %%
# Checking total Null Values present per Features for Categorical Variables

categorical_data[cat_imp.index].isnull().sum()
# Out:
# MSZoning          4
# Utilities         2
# Exterior1st       1
# Exterior2nd       1
# MasVnrType       24
# BsmtQual         81
# BsmtCond         82
# BsmtExposure     82
# BsmtFinType1     79
# BsmtFinType2     80
# Electrical        1
# KitchenQual       1
# Functional        2
# GarageType      157
# GarageFinish    159
# GarageQual      159
# GarageCond      159
# SaleType          1
# dtype: int64

# %%
# Creating DataFrame of Modes per Categorical Feature

m = categorical_data[cat_imp.index].mode()
m
# Out:
#   MSZoning Utilities Exterior1st Exterior2nd MasVnrType BsmtQual BsmtCond  \
# 0       RL    AllPub     VinylSd     VinylSd       None       TA       TA
#
#   BsmtExposure BsmtFinType1 BsmtFinType2 Electrical KitchenQual Functional  \
# 0           No          Unf          Unf      SBrkr          TA        Typ
#
#   GarageType GarageFinish GarageQual GarageCond SaleType
# 0     Attchd          Unf         TA         TA       WD

# %%
# Replacing Null Values with Mode Values per Categorical Feature

for i in cat_imp.index:
    categorical_data[i] = categorical_data[i].fillna(m[i][0])

# %%
# Checking total Null Values present per Features for Categorical Variables

categorical_data[cat_imp.index].isnull().sum()
# Out:
# MSZoning        0
# Utilities       0
# Exterior1st     0
# Exterior2nd     0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# Electrical      0
# KitchenQual     0
# Functional      0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# SaleType        0
# dtype: int64

# %%
# Thus Null Values of Categorical Variable is handled
# Now, Null Values of Numerical Features to be handled

num_imp
# Out:
#                 Values
# LotFrontage   0.166495
# MasVnrArea    0.007879
# BsmtFinSF1    0.000343
# BsmtFinSF2    0.000343
# BsmtUnfSF     0.000343
# TotalBsmtSF   0.000343
# BsmtFullBath  0.000685
# BsmtHalfBath  0.000685
# GarageYrBlt   0.054471
# GarageCars    0.000343
# GarageArea    0.000343

# %%
# Creating Functions for Boxplot and Distribution plot for Numerical Variables

from scipy import stats

def BoxDist(data, label):
    plt.subplots(1, 2, figsize=(15,5))

    plt.subplot(1, 3, 1)
    sns.boxplot(y=label, data=data)
    plt.title(label + ' ' +'Boxplot')
    
    plt.subplot(1, 3, 2)
    sns.distplot(data[label], hist=True, bins=data[label].nunique(), fit=stats.norm, label=label)
    plt.axvline(np.mean(data[label]), ls='--', c='r', label="Mean")
    plt.axvline(np.median(data[label]), ls='--', c='g', label="Median")
    plt.ylabel('Counts')
    plt.title(label + ' ' +'Distribution')
    plt.legend()
    
    plt.show()

# %%
# First let us check the plots for the numerical features those need to processed by imputation techniques for missing value

for i in num_imp.index:
    BoxDist(numerical_data, i)

# %%
# Replacing Null Values with Median Values per Numerical Feature as all having outlier

for i in numerical_data.columns:
    numerical_data[i] = numerical_data[i].fillna(numerical_data[i].median())

# %%
# Cross-checking total Null Values present per Features for Numerical Variables

numerical_data[num_imp.index].isnull().sum()
# Out:
# LotFrontage     0
# MasVnrArea      0
# BsmtFinSF1      0
# BsmtFinSF2      0
# BsmtUnfSF       0
# TotalBsmtSF     0
# BsmtFullBath    0
# BsmtHalfBath    0
# GarageYrBlt     0
# GarageCars      0
# GarageArea      0
# dtype: int64

# %% [markdown]
# # Part-III
# # Handling Outliers

# %%
# We know that some features contains outliers, but removing outliers in this stage may lead to loss of information
# Later, prior model buliding we'll handle this by scaling or transformation

# We'll not remove outliers now!

# As dataset conatins many more features, we need to check for multi-collinearity

# %%
# Checking final shape of categorical & numerical data: 

print(categorical_data.shape)
print(numerical_data.shape)
# Out:
# (2919, 43)
# (2919, 31)

# %%
del cat_imp, cat_ord_var, categorical_data_drop
del num_imp, numerical_data_drop

# %% [markdown]
# # Part-IV
# # Encoding of Categorical Variables
#
# ### (Level Encoder)

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

# %%
numerical_features = numerical_data.columns
categorical_features = categorical_data.columns

# %%
encoded_cat_data = pd.DataFrame()
for features in categorical_features:
    encoded_cat_data[features] = labelencoder.fit_transform(categorical_data[features])

# %%
encoded_cat_data.shape
# Out:
# (2919, 43)

# %%
encoded_cat_data.head(15)
# Out:
#     MSZoning  Street  LotShape  LandContour  Utilities  LotConfig  LandSlope  \
# 0          3       1         3            3          0          4          0
# 1          3       1         3            3          0          2          0
# 2          3       1         0            3          0          4          0
# 3          3       1         0            3          0          0          0
# 4          3       1         0            3          0          2          0
# 5          3       1         0            3          0          4          0
# 6          3       1         3            3          0          4          0
# 7          3       1         0            3          0          0          0
# 8          4       1         3            3          0          4          0
# 9          3       1         3            3          0          0          0
# 10         3       1         3            3          0          4          0
# ...

# %% [markdown]
# # Part-V
# # EDA

# %%
# Segregating Train & Test dataset

numerical_train = numerical_data[:len(train_data)]
numerical_test = numerical_data[len(train_data):]

cat_encoded_train = encoded_cat_data[:len(train_data)]
cat_encoded_test = encoded_cat_data[len(train_data):]

# %%
print(numerical_train.shape)
print(numerical_test.shape)
print(cat_encoded_train.shape)
print(cat_encoded_test.shape)
# Out:
# (1460, 31)
# (1459, 31)
# (1460, 43)
# (1459, 43)

# %%
# Plots of Numerical Features vs Response Variable

numerical_train['SalePrice'] = y
fig, axs = plt.subplots( figsize=(18, 110))
for i, col in enumerate(numerical_train.columns, 1):
    plt.subplot(numerical_train.shape[1], 4, i)
    sns.scatterplot(data=numerical_train, x=col, y='SalePrice', hue='SalePrice', palette="rocket")

# %%
corr_matrix_num = numerical_train.corr()
plt.figure(figsize=(30, 30))
sns.heatmap(corr_matrix_num, annot=True, square=True, cmap='flare', vmax=0.8, vmin=-0.5)
plt.show()

# %%
# Checking for correlation >0.5

plt.figure(figsize=(30, 30))
sns.heatmap(corr_matrix_num[abs(corr_matrix_num)>0.5], annot=True, square=True, cmap='coolwarm', vmax=0.75, vmin=-0.4)
plt.show()

# %%
# There are few features relatively high correlation with SalePrice

plt.figure(figsize=(9,6))
sns.regplot(data=numerical_train, x='YearBuilt', y='SalePrice', scatter_kws={'alpha':0.2})
plt.title('YearBuilt'+' vs '+'SalePrice', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(9,6))
sns.regplot(data=numerical_train, x='YearRemodAdd', y='SalePrice', scatter_kws={'alpha':0.2})
plt.title('YearRemodAdd'+' vs '+'SalePrice', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(9,6))
sns.regplot(data=numerical_train, x='TotalBsmtSF', y='SalePrice', scatter_kws={'alpha':0.2})
plt.title('TotalBsmtSF'+' vs '+'SalePrice', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(9,6))
sns.regplot(data=numerical_train, x='1stFlrSF', y='SalePrice', scatter_kws={'alpha':0.2})
plt.title('1stFlrSF'+' vs '+'SalePrice', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(9,6))
sns.regplot(data=numerical_train, x='GrLivArea', y='SalePrice', scatter_kws={'alpha':0.2})
plt.title('GrLivArea'+' vs '+'SalePrice', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(9,6))
sns.regplot(data=numerical_train, x='FullBath', y='SalePrice', scatter_kws={'alpha':0.2})
plt.title('FullBath'+' vs '+'SalePrice', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(9,6))
sns.regplot(data=numerical_train, x='TotRmsAbvGrd', y='SalePrice', scatter_kws={'alpha':0.2})
plt.title('TotRmsAbvGrd'+' vs '+'SalePrice', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(9,6))
sns.regplot(data=numerical_train, x='GarageCars', y='SalePrice', scatter_kws={'alpha':0.2})
plt.title('GarageCars'+' vs '+'SalePrice', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(9,6))
sns.regplot(data=numerical_train, x='GarageArea', y='SalePrice', scatter_kws={'alpha':0.2})
plt.title('GarageArea'+' vs '+'SalePrice', fontsize=12)
plt.show()

# %%
corr_matrix_cat = cat_encoded_train.corr(method='spearman')
plt.figure(figsize=(30, 30))
sns.heatmap(corr_matrix_cat, annot=True, square=True, cmap='flare', vmax=0.8, vmin=-0.5)
plt.show()

# %%
# Checking for correlation >0.5

plt.figure(figsize=(30, 30))
sns.heatmap(corr_matrix_cat[abs(corr_matrix_cat)>0.5], annot=True, square=True, cmap='coolwarm', vmax=0.75, vmin=-0.4)
plt.show()

# %%
cat_encoded_train = cat_encoded_train.drop(columns=['LandSlope', 'Exterior2nd', 'ExterQual', 'BsmtQual', 'KitchenQual',
                                                     'GarageFinish'], axis=1)
cat_encoded_test = cat_encoded_test.drop(columns=['LandSlope', 'Exterior2nd', 'ExterQual', 'BsmtQual', 'KitchenQual',
                                                     'GarageFinish'], axis=1)

# %%
print(cat_encoded_train.shape)
print(cat_encoded_test.shape)
# Out:
# (1460, 37)
# (1459, 37)

# %%
def plot_feature(df, feature):
    
    fig, axs = plt.subplots( figsize=(16, 8))
        
    plt.subplot(1, 2, 1)
    (mu, sigma) = stats.norm.fit(df[feature])
    sns.distplot(df[feature], kde=True, hist=True, fit=stats.norm, color="b")
    plt.title(feature + 'Distribution vs Normal Distribution', fontsize=16)
    plt.xlabel(feature, fontsize=12)
    plt.ylabel("Frequency %", fontsize=12)
    plt.legend(['Distribution ($\mu=$ {:.2f} and $\sigma=$ {:.2f})'.format(mu, sigma)], loc='upper center')
    
    plt.subplot(1, 2, 2)
    observation = df[feature]
    z = (observation-np.mean(observation))/np.std(observation)
    stats.probplot(z, dist="norm", plot=plt)
    plt.title("Normal Q-Q plot of " + feature, fontsize=16)
    
    plt.show()

# %%
y = pd.DataFrame(y)

# %%
plot_feature(y, 'SalePrice')

# %%
y['LogSalePrice'] = y.SalePrice.apply(np.log10)

# %%
plot_feature(y, 'LogSalePrice')

# %%
numerical_train.drop(columns=['SalePrice'], axis=1, inplace=True)
numerical_train.shape
# Out:
# (1460, 31)

# %%
# Calculating Variance Inflation Factor

from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['Features'] = numerical_train.columns
vif['VIF'] = [variance_inflation_factor(numerical_train.to_numpy(), i) for i in range(numerical_train.shape[1])]

print(vif.to_markdown())
# Out:
# |    | Features      |         VIF |
# |---:|:--------------|------------:|
# |  0 | LotFrontage   |    15.4964  |
# |  1 | LotArea       |     2.58785 |
# |  2 | YearBuilt     | 17119.8     |
# |  3 | YearRemodAdd  | 12901.8     |
# |  4 | MasVnrArea    |     1.81975 |
# |  5 | BsmtFinSF1    |   inf       |
# |  6 | BsmtFinSF2    |   inf       |
# |  7 | BsmtUnfSF     |   inf       |
# |  8 | TotalBsmtSF   |   inf       |
# |  9 | 1stFlrSF      |   inf       |
# | 10 | 2ndFlrSF      |   inf       |
# | 11 | LowQualFinSF  |   inf       |
# | 12 | GrLivArea     |   inf       |
# | 13 | BsmtFullBath  |     3.57499 |
# | 14 | BsmtHalfBath  |     1.20616 |
# | 15 | FullBath      |    20.8006  |
# | 16 | HalfBath      |     3.1973  |
# | 17 | BedroomAbvGr  |    28.6421  |
# | 18 | KitchenAbvGr  |    29.6279  |
# | 19 | TotRmsAbvGrd  |    81.9617  |
# | 20 | Fireplaces    |     2.91449 |
# | 21 | GarageYrBlt   | 20262.3     |
# | 22 | GarageCars    |    35.7113  |
# ...

# %%
# Checking Null value in vif

vif_null = vif[vif['VIF'].isna()]
vif_null
# Out:
# Empty DataFrame
# Columns: [Features, VIF]
# Index: []

# %%
#Creating Function to find vif, feature corresnponding to Max VIF Value and max VIF Value

def VIFMax(input_x):
    
    from statsmodels.stats.outliers_influence import variance_inflation_factor
    
    vif = pd.DataFrame()
    vif['Features'] = input_x.columns
    vif['VIF'] = [variance_inflation_factor(input_x.to_numpy(), i) for i in range(input_x.shape[1])]
    
    loc = vif.VIF.idxmax()
    feature = vif._get_value(loc, 'Features')
    max_val = vif.VIF.max()

    return vif, feature, max_val

# %%
# Creating a Function to remove required feature

def NewDF(df, col_list):
    df.drop(columns=col_list, axis=1, inplace=True)
    
    return df

# %%
# Calculating VIF and finding the max VIF Value by VIFMax function

vif, max_feature, max_vif = VIFMax(numerical_train)
print(max_feature, ':', max_vif)
# Out:
# BsmtFinSF1 : inf

# %%
#(1) ...Removing feature --> 'BsmtFinSF1'

numerical_train = NewDF(numerical_train, ['BsmtFinSF1'])

# %%
# Calculating VIF of new set of input variables and finding the max VIF Value

vif, max_feature, max_vif = VIFMax(numerical_train)
print(max_feature, ':', max_vif)
# Out:
# 1stFlrSF : inf

# %%
#(2) ...Removing feature --> '1stFlrSF'

numerical_train = NewDF(numerical_train, ['1stFlrSF'])

# %%
# Calculating VIF of new set of input variables and finding the max VIF Value

vif, max_feature, max_vif = VIFMax(numerical_train)
print(max_feature, ':', max_vif)
# Out:
# GarageYrBlt : 20262.262287846635

# %%
#(3) ...Removing feature --> 'GarageYrBlt'

numerical_train = NewDF(numerical_train, ['GarageYrBlt'])

# %%
# Calculating VIF of new set of input variables and finding the max VIF Value

vif, max_feature, max_vif = VIFMax(numerical_train)
print(max_feature, ':', max_vif)
# Out:
# YearBuilt : 9809.825821863196

# %%
#(4) ...Removing feature --> 'YearBuilt'

numerical_train = NewDF(numerical_train, ['YearBuilt'])

# %%
# Calculating VIF of new set of input variables and finding the max VIF Value

vif, max_feature, max_vif = VIFMax(numerical_train)
print(max_feature, ':', max_vif)
# Out:
# GrLivArea : 100.08077929692938

# %%
#(5) ...Removing feature --> 'GrLivArea'

numerical_train = NewDF(numerical_train, ['GrLivArea'])

# %%
# Calculating VIF of new set of input variables and finding the max VIF Value

vif, max_feature, max_vif = VIFMax(numerical_train)
print(max_feature, ':', max_vif)
# Out:
# TotRmsAbvGrd : 65.62188858905913

# %%
#(6) ...Removing feature --> 'TotRmsAbvGrd'

numerical_train = NewDF(numerical_train, ['TotRmsAbvGrd'])

# %%
# Calculating VIF of new set of input variables and finding the max VIF Value

vif, max_feature, max_vif = VIFMax(numerical_train)
print(max_feature, ':', max_vif)
# Out:
# YearRemodAdd : 46.399297678783135

# %%
#(7) ...Removing feature --> 'YearRemodAdd'

numerical_train = NewDF(numerical_train, ['YearRemodAdd'])

# %%
# Calculating VIF of new set of input variables and finding the max VIF Value

vif, max_feature, max_vif = VIFMax(numerical_train)
print(max_feature, ':', max_vif)
# Out:
# GarageCars : 34.223246887213776

# %%
#(8) ...Removing feature --> 'GarageCars'

numerical_train = NewDF(numerical_train, ['GarageCars'])

# %%
# Calculating VIF of new set of input variables and finding the max VIF Value

vif, max_feature, max_vif = VIFMax(numerical_train)
print(max_feature, ':', max_vif)
# Out:
# TotalBsmtSF : 22.203556031805157

# %%
#(9) ...Removing feature --> 'TotalBsmtSF'

numerical_train = NewDF(numerical_train, ['TotalBsmtSF'])

# %%
# Calculating VIF of new set of input variables and finding the max VIF Value

vif, max_feature, max_vif = VIFMax(numerical_train)
print(max_feature, ':', max_vif)
# Out:
# BedroomAbvGr : 19.763146662605518

# %%
#(10) ...Removing feature --> 'BedroomAbvGr'

numerical_train = NewDF(numerical_train, ['BedroomAbvGr'])

# %%
# Calculating VIF of new set of input variables and finding the max VIF Value

vif, max_feature, max_vif = VIFMax(numerical_train)
print(max_feature, ':', max_vif)
# Out:
# FullBath : 15.54757278274454

# %%
#(11) ...Removing feature --> 'FullBath'

numerical_train = NewDF(numerical_train, ['FullBath'])

# %%
# Calculating VIF of new set of input variables and finding the max VIF Value

vif, max_feature, max_vif = VIFMax(numerical_train)
print(max_feature, ':', max_vif)
# Out:
# LotFrontage : 12.134976149083093

# %%
#(12) ...Removing feature --> 'LotFrontage'

numerical_train = NewDF(numerical_train, ['LotFrontage'])

# %%
# Calculating VIF of new set of input variables and finding the max VIF Value

vif, max_feature, max_vif = VIFMax(numerical_train)
print(max_feature, ':', max_vif)
# Out:
# GarageArea : 7.627269726177148

# %%
#(13) ...Removing feature --> 'GarageArea'

numerical_train = NewDF(numerical_train, ['GarageArea'])

# %%
# Calculating VIF of new set of input variables and finding the max VIF Value

vif, max_feature, max_vif = VIFMax(numerical_train)
print(max_feature, ':', max_vif)
# Out:
# KitchenAbvGr : 5.989944250670868

# %%
#(14) ...Removing feature --> 'KitchenAbvGr'

numerical_train = NewDF(numerical_train, ['KitchenAbvGr'])

# %%
# Calculating VIF of new set of input variables and finding the max VIF Value

vif, max_feature, max_vif = VIFMax(numerical_train)
print(max_feature, ':', max_vif)
# Out:
# 2ndFlrSF : 2.8665044812342795

# %%
print(vif.to_markdown())
# Out:
# |    | Features      |     VIF |
# |---:|:--------------|--------:|
# |  0 | LotArea       | 2.30344 |
# |  1 | MasVnrArea    | 1.54152 |
# |  2 | BsmtFinSF2    | 1.17314 |
# |  3 | BsmtUnfSF     | 2.09689 |
# |  4 | 2ndFlrSF      | 2.8665  |
# |  5 | LowQualFinSF  | 1.0386  |
# |  6 | BsmtFullBath  | 1.85514 |
# |  7 | BsmtHalfBath  | 1.09056 |
# |  8 | HalfBath      | 2.65354 |
# |  9 | Fireplaces    | 2.41968 |
# | 10 | WoodDeckSF    | 1.78871 |
# | 11 | OpenPorchSF   | 1.69526 |
# | 12 | EnclosedPorch | 1.18956 |
# | 13 | 3SsnPorch     | 1.02149 |
# | 14 | ScreenPorch   | 1.15418 |
# | 15 | PoolArea      | 1.03591 |
# | 16 | MiscVal       | 1.01264 |

# %%
num_predictors = numerical_train.columns

# %%
dataset.shape
# Out:
# (1459, 17)

# %%
del dataset_test

# %%
print(cat_encoded_test.shape)
print(numerical_test.shape)
# Out:
# (1459, 37)
# (1459, 17)

# %%
dataset_test = numerical_train.merge()

# %%
dataset_test = pd.concat([numerical_test, cat_encoded_test], axis=1, ignore_index=True, verify_integrity=True)
dataset_test.shape
# Out:
# (2918, 54)

# %%
dataset_test.isnull().sum()
# Out:
# LotArea          1459
# MasVnrArea       1459
# BsmtFinSF2       1459
# BsmtUnfSF        1459
# 2ndFlrSF         1459
# LowQualFinSF     1459
# BsmtFullBath     1459
# BsmtHalfBath     1459
# HalfBath         1459
# Fireplaces       1459
# WoodDeckSF       1459
# OpenPorchSF      1459
# EnclosedPorch    1459
# 3SsnPorch        1459
# ScreenPorch      1459
# PoolArea         1459
# MiscVal          1459
# MSZoning         1459
# Street           1459
# LotShape         1459
# LandContour      1459
# Utilities        1459
# LotConfig        1459
# Neighborhood     1459
# Condition1       1459
# Condition2       1459
# BldgType         1459
# HouseStyle       1459
# RoofStyle        1459
# RoofMatl         1459
# Exterior1st      1459
# MasVnrType       1459
# ExterCond        1459
# Foundation       1459
# BsmtCond         1459
# BsmtExposure     1459
# BsmtFinType1     1459
# BsmtFinType2     1459
# Heating          1459
# HeatingQC        1459
# CentralAir       1459
# ...

# %%
# It seems LogSalePrice transformation is better
#Vast ranges for the features are seen, hence we'll build the model with scaled numerical data
# Transforming Dataset for model building

numerical_test = numerical_test[num_predictors]
#y.drop(columns=['SalePrice'], axis=1, inplace=True)

dataset_train = pd.concat([numerical_train, cat_encoded_train], axis=1)
#dataset_test = pd.concat([numerical_test, cat_encoded_test], axis=1)

print('Shape of Final Train Dataset: ', dataset_train.shape)
#print('Shape of Final Test Dataset: ', dataset_test.shape)
print('Shape of Response DataFrame: ', y.shape)
# Out:
# Shape of Final Train Dataset:  (1460, 54)
# Shape of Response DataFrame:  (1460, 1)

# %% [markdown]
# # Part-VI
# # Model Building

# %% [markdown]
# ### Preparing Input Dataset

# %%
X_train = pd.get_dummies(data=dataset_train, drop_first=True)
X_train.shape
# Out:
# (1460, 54)

# %%
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
dataset_scaled = scaler.fit_transform(dataset_new)
dataset_scaled = pd.DataFrame(dataset_scaled, columns=[dataset_new.columns])

X_train = dataset_scaled[:len(train_data)]
X_test = dataset_scaled[len(train_data):]

print(X_train.shape)
print(y.shape)
print(X_test.shape)
# Out:
# (1460, 37)
# (1460,)
# (1459, 37)

# %% [markdown]
# ### Model Building through Ensemble Method

# %%
from sklearn.linear_model import Ridge, RidgeCV, LassoCV, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, StackingRegressor
from xgboost import XGBRegressor
from mlxtend.regressor import StackingCVRegressor
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold
import statsmodels.api as sma

# %%
kf_inner = KFold(n_splits=5, shuffle=True, random_state=123)
kf_outer = KFold(n_splits=10, shuffle=True, random_state=123)

# %%
model = Ridge(normalize=True, random_state=123)
param = dict()
param['alpha'] = [5, 10, 12, 15]
param['solver'] = ['lsqr', 'sag', 'saga']

search = GridSearchCV(model, param, scoring='neg_root_mean_squared_error', n_jobs=1, cv=kf_inner, refit=True)
result = search.fit(X_train, y)
scores = -cross_val_score(model, X_train, y, cv=kf_outer, scoring='neg_root_mean_squared_error')

print(f'Best {type(model).__name__} Parameter(s): {result.best_params_}')
print("RMSE: %0.5f (+/- %0.2f) [%s]" % (scores.mean(), scores.std(), type(model).__name__))
# Out:
# Best Ridge Parameter(s): {'alpha': 5, 'solver': 'saga'}
# RMSE: 0.09301 (+/- 0.01) [Ridge]

# %%
model = Lasso(random_state=123)
space = dict()
space['alpha'] = [1, 2, 5]

search = GridSearchCV(model, space, scoring='neg_root_mean_squared_error', n_jobs=1, cv=kf_inner, refit=True)
result = search.fit(X_train, y)
scores = -cross_val_score(model, X_train, y, cv=kf_outer, scoring='neg_root_mean_squared_error')

print(f'Best {type(model).__name__} Parameter(s): {result.best_params_}')
print("RMSE: %0.5f (+/- %0.2f) [%s]" % (scores.mean(), scores.std(), type(model).__name__))
# Out:
# Best Lasso Parameter(s): {'alpha': 1}
# RMSE: 0.17222 (+/- 0.01) [Lasso]

# %%
model = RidgeCV()
space = dict()
space['alphas'] = [1, 2, 5, 10]

search = GridSearchCV(model, space, scoring='neg_root_mean_squared_error', n_jobs=1, cv=kf_inner, refit=True)
result = search.fit(X_train, y)
scores = -cross_val_score(model, X_train, y, cv=kf_outer, scoring='neg_root_mean_squared_error')

print(f'Best {type(model).__name__} Parameter(s): {result.best_params_}')
print("RMSE: %0.5f (+/- %0.2f) [%s]" % (scores.mean(), scores.std(), type(model).__name__))
# Out:
# Best RidgeCV Parameter(s): {'alphas': 10}
# RMSE: 0.08775 (+/- 0.01) [RidgeCV]

# %%
model = LassoCV(random_state=123)
space = dict()
space['n_alphas'] = [50, 100, 200, 500]
space['eps']=[0.001, 0.002, 0.005]
space['max_iter']=[1000, 2000, 5000]
space['cv'] = [5, 10, 15]

search = GridSearchCV(model, space, scoring='neg_root_mean_squared_error', n_jobs=1, cv=kf_inner, refit=True)
result = search.fit(X_train, y)
scores = -cross_val_score(model, X_train, y, cv=kf_outer, scoring='neg_root_mean_squared_error')

print(f'Best {type(model).__name__} Parameter(s): {result.best_params_}')
print("RMSE: %0.5f (+/- %0.2f) [%s]" % (scores.mean(), scores.std(), type(model).__name__))
# Out:
# Best LassoCV Parameter(s): {'cv': 5, 'eps': 0.001, 'max_iter': 1000, 'n_alphas': 50}
# RMSE: 0.08892 (+/- 0.01) [LassoCV]

# %%
model = RandomForestRegressor(random_state=123)
space = dict()
space['n_estimators'] = [100, 200, 500]
space['max_features']=[1, 2, 5]

search = GridSearchCV(model, space, scoring='neg_root_mean_squared_error', n_jobs=1, cv=kf_inner, refit=True)
result = search.fit(X_train, y)
scores = -cross_val_score(model, X_train, y, cv=kf_outer, scoring='neg_root_mean_squared_error')

print(f'Best {type(model).__name__} Parameter(s): {result.best_params_}')
print("RMSE: %0.5f (+/- %0.2f) [%s]" % (scores.mean(), scores.std(), type(model).__name__))
# Out:
# Best RandomForestRegressor Parameter(s): {'max_features': 5, 'n_estimators': 500}
# RMSE: 0.08155 (+/- 0.00) [RandomForestRegressor]

# %%
model = GradientBoostingRegressor(random_state=123)
space = dict()
space['n_estimators'] = [100, 200, 500]
space['max_features']=[1, 2, 5]

search = GridSearchCV(model, space, scoring='neg_root_mean_squared_error', n_jobs=1, cv=kf_inner, refit=True)
result = search.fit(X_train, y)
scores = -cross_val_score(model, X_train, y, cv=kf_outer, scoring='neg_root_mean_squared_error')

print(f'Best {type(model).__name__} Parameter(s): {result.best_params_}')
print("RMSE: %0.5f (+/- %0.2f) [%s]" % (scores.mean(), scores.std(), type(model).__name__))
# Out:
# Best GradientBoostingRegressor Parameter(s): {'max_features': 5, 'n_estimators': 500}
# RMSE: 0.07846 (+/- 0.00) [GradientBoostingRegressor]

# %%
model = XGBRegressor(random_state=123)
space = dict()
space['n_estimators'] = [100, 200, 500]
space['learning_rate']=[0.1, 0.2, 0.3]
space['gamma']=[0.1, 0.2, 0.3]

search = GridSearchCV(model, space, scoring='neg_root_mean_squared_error', n_jobs=1, cv=kf_inner, refit=True)
result = search.fit(X_train, y)
scores = -cross_val_score(model, X_train, y, cv=kf_outer, scoring='neg_root_mean_squared_error')

print(f'Best {type(model).__name__} Parameter(s): {result.best_params_}')
print("RMSE: %0.5f (+/- %0.2f) [%s]" % (scores.mean(), scores.std(), type(model).__name__))
# Out:
# Best XGBRegressor Parameter(s): {'gamma': 0.1, 'learning_rate': 0.1, 'n_estimators': 100}
# RMSE: 0.08037 (+/- 0.01) [XGBRegressor]

# %%
# Different Regression Models - Base Models

rfr = RandomForestRegressor(n_estimators=500, max_features=5, random_state=123)
gbr = GradientBoostingRegressor(n_estimators=500, max_features=5, random_state=123)
xgbr = XGBRegressor(n_estimators=100, learning_rate=0.1, gamma=0.1)
stacking_CV_reg = StackingCVRegressor(regressors=[gbr, xgbr], 
                                 meta_regressor=rfr, cv=10, use_features_in_secondary=True, random_state=123)

print('10-fold cross validation scores:\n')

for reg, label in zip([rfr, gbr, xgbr, stacking_CV_reg], ['RF Regressor', 'GB Regressor', 'XGB Regressor', 'StackingCVRegressor']):
    
    scores = -cross_val_score(reg, X_train, y, cv=kf_outer, scoring='neg_root_mean_squared_error')
    
    print("RMSE: %0.5f (+/- %0.2f) [%s]" % (scores.mean(), scores.std(), label))
# Out:
# 10-fold cross validation scores:
#
# RMSE: 0.07815 (+/- 0.01) [RF Regressor]
# RMSE: 0.07497 (+/- 0.01) [GB Regressor]
# RMSE: 0.08250 (+/- 0.01) [XGB Regressor]
# RMSE: 0.07313 (+/- 0.01) [StackingCVRegressor]

# %%
# Different Regression Models - Base Models

lassoCV = LassoCV(cv=5, eps=0.001, max_iter=1000, n_alphas=100, random_state=123)
ridgeCV = RidgeCV(alphas=10)
gbr = GradientBoostingRegressor(n_estimators=500, max_features=5, random_state=123)

stacking_CV_reg = StackingCVRegressor(regressors=[ridgeCV, lassoCV], 
                                 meta_regressor=gbr, cv=10, use_features_in_secondary=True, random_state=123)

print('10-fold cross validation scores:\n')

for reg, label in zip([ridgeCV, lassoCV, gbr, stacking_CV_reg], ['RidgeCV', 'LassoCV', 'GB Regressor', 'StackingCVRegressor']):
    
    scores = -cross_val_score(reg, X_train, y, cv=kf_outer, scoring='neg_root_mean_squared_error')
    
    print("RMSE: %0.5f (+/- %0.2f) [%s]" % (scores.mean(), scores.std(), label))
# Out:
# 10-fold cross validation scores:
#
# RMSE: 0.05629 (+/- 0.01) [RidgeCV]
# RMSE: 0.05608 (+/- 0.01) [LassoCV]
# RMSE: 0.05918 (+/- 0.01) [GB Regressor]
# RMSE: 0.05704 (+/- 0.01) [StackingCVRegressor]

# %%
# %%time

# Finding best hyper-parameter through GridSearchCV

ridge = Ridge(random_state=123)
lasso = Lasso(random_state=123)
rfr = RandomForestRegressor(random_state=123)

stacking_CV_reg = StackingCVRegressor(regressors=[ridge, lasso], 
                                    meta_regressor=rfr, use_features_in_secondary=True, random_state=123)

params = {'lasso__alpha': [1.0, 1.5, 2.0],
          'ridge__alpha': [15.0, 18.0, 20.0],
            'meta_regressor__n_estimators': [10, 100, 500]}

gridCV = GridSearchCV(estimator=stacking_CV_reg, param_grid=params, cv=5, refit=True)

gridCV.fit(X_train, y)

print("Best: %f using %s" % (gridCV.best_score_, gridCV.best_params_))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     873                 return results
#     874
# --> 875             self._run_search(evaluate_candidates)
#     876
#     877             # multimetric is determined here because in the case of a callable
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1377     def _run_search(self, evaluate_candidates):
#    1378         """Search all candidates in param_grid"""
# -> 1379         evaluate_candidates(ParameterGrid(self.param_grid))
#    1380
#    1381
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     820                     )
#     821
# ...

# %%
# Different Regression Models - Base Models

ridge = Ridge(alpha=15.0, random_state=123)
lasso = Lasso(alpha=1.0, random_state=123)
rfr = RandomForestRegressor(n_estimators=500, random_state=123)
lassoCV = LassoCV(cv=10, max_iter=1000, normalize=True, random_state=123)
ridgeCV = RidgeCV(cv=10, normalize=True)
gbr = GradientBoostingRegressor(random_state=123)
xgbr = XGBRegressor(random_state=123)

# %%
# %%time

stacking_CV_reg = StackingCVRegressor(regressors=[ridge, lasso, ridgeCV, rfr, gbr, xgbr], 
                                 meta_regressor=lassoCV, cv=15, use_features_in_secondary=True, random_state=123)

print('10-fold cross validation scores:\n')

for reg, label in zip([ridge, lasso, ridgeCV, lassoCV, rfr, gbr, xgbr, stacking_CV_reg], ['Ridge', 'Lasso', 'RidgeCV', 
                            'LassoCV', 'Random Forest', 'GB Regressor', 'XGB Regressor', 'StackingCVRegressor']):
    
    kf = KFold(10, shuffle=True, random_state=123).get_n_splits(X_train)
    scores = -cross_val_score(reg, X_train, y, cv=kf, scoring='neg_root_mean_squared_error')
    
    print("RMSE: %0.5f (+/- %0.2f) [%s]" % (scores.mean(), scores.std(), label))
# Out:
# 10-fold cross validation scores:
#
# RMSE: 0.05558 (+/- 0.01) [Ridge]
# RMSE: 0.17313 (+/- 0.01) [Lasso]
# RMSE: 0.05834 (+/- 0.01) [RidgeCV]
# RMSE: 0.05623 (+/- 0.01) [LassoCV]
# RMSE: 0.06252 (+/- 0.01) [Random Forest]
# RMSE: 0.05820 (+/- 0.01) [GB Regressor]
# RMSE: 0.06347 (+/- 0.01) [XGB Regressor]
# RMSE: 0.05344 (+/- 0.01) [StackingCVRegressor]
# Wall time: 37min 22s

# %%
# %%time

stacking_CV_reg_1 = StackingCVRegressor(regressors=[ridge, ridgeCV, rfr, gbr, xgbr], 
                                 meta_regressor=lassoCV, cv=15, use_features_in_secondary=True, random_state=123)

print('15-fold cross validation scores:\n')

for reg, label in zip([ridge, ridgeCV, lassoCV, rfr, gbr, xgbr, stacking_CV_reg_1], ['Ridge', 'RidgeCV', 
                            'LassoCV', 'Random Forest', 'GB Regressor', 'XGB Regressor', 'StackingCVRegressor-1']):
    
    kf = KFold(15, shuffle=True, random_state=123).get_n_splits(X_train)
    scores = -cross_val_score(reg, X_train, y, cv=kf, scoring='neg_root_mean_squared_error')
    
    print("RMSE: %0.5f (+/- %0.2f) [%s]" % (scores.mean(), scores.std(), label))
# Out:
# 15-fold cross validation scores:
#
# RMSE: 2856417662.69173 (+/- 7284057095.83) [Lin Reg]
# RMSE: 0.05594 (+/- 0.01) [RidgeCV]
# RMSE: 0.05435 (+/- 0.01) [LassoCV]
# RMSE: 0.05935 (+/- 0.01) [Random Forest]
# RMSE: 0.05518 (+/- 0.01) [GB Regressor]
# RMSE: 0.05852 (+/- 0.01) [XGB Regressor]
# RMSE: 0.05477 (+/- 0.01) [StackingCVRegressor]

# %%
# Reg Plot of Actual Vs Predicted Response Variable by statsmodels.regression.linear_model>>OLS
stacking_CV_reg.fit(X_train, y)
y_pred = stacking_CV_reg.predict(X_train)

plt.figure(figsize=(16,9))

sns.regplot(x=y, y=y_pred, scatter_kws={'alpha':0.5}, color='tomato')
plt.xlabel('LogSalePrice_Actual', fontsize=12)
plt.ylabel('LogSalePrice_Predicted', fontsize=12)
plt.title('Actual Vs Prediction on Train Data')

plt.show()

# %% [markdown]
# # Part-VII
# ## Prediction of SalePrice from 'test' data using best model

# %%
# Choosing/selecting best performing model

model = stacking_CV_reg

# %%
# Creating DataFrame of Test Prediction

test_pred = model.predict(X_test)

# %%
# Creating csv file by adding a column of predicted SalePrice with availavle test data

sub_data['SalePrice'] = 10**test_pred
sub_data.set_index('Id', inplace=True)

print('Printing shape of Test Dataset: ', test_data.shape)
print('Printing shape of Submission Dataset: ', sub_data.shape)
# Out:
# Printing shape of Test Dataset:  (1459, 80)
# Printing shape of Submission Dataset:  (1459, 1)

# %%
sub_data.head(15)
# Out:
#           SalePrice
# Id
# 1461  153562.380545
# 1462  161027.594117
# 1463  210211.872914
# 1464  206740.520951
# 1465  216836.749990
# 1466  203415.349418
# 1467  172397.423025
# 1468  177382.489883
# 1469  180372.100394
# 1470  149751.124056
# 1471  208502.869613
# 1472  114757.181473
# 1473  111073.395308
# 1474  143689.755232
# 1475  126798.462686

# %%
# Exporting Predicted data to CSV File

sub_data.to_csv('submission.csv')

# %% [markdown]
# ## -----------------------------------------------E  N  D--------------------------------------------------------
